# %%
import csv
import json
import pandas as pd
import requests

# %%
queries = ['funko', 'figure', 'boneco']
ids = []
limit = 50
for query in queries:
  url = f"https://api.mercadolibre.com/sites/MLA/search?q={query}&limit={limit}#json"
  response = requests.get(url)
  data = response.json()
  for item in data['results']:
    ids.append(item['id'])

# %%
len(ids)
# Out:
# 150

# %%
items = []
for id in ids:
  url = f"https://api.mercadolibre.com/items/{id}"
  response = requests.get(url)
  data = response.json()
  items.append(data)

# %%
items[0]
clear_items = []
for item in items:
  id = item['id']
  name = item['title']
  category_id = item['category_id']
  price = item['price']
  clear_item = {
      'id': id,
      'name': name,
      'category_id': category_id,
      'price': price
  }
  clear_items.append(clear_item)

# %%
df = pd.DataFrame(clear_items)
df.head()
# Out:
#               id                                               name  \
# 0  MLA1424067733            Funko Pop Harry Potter 149 Harry Potter
# 1  MLA1807764998                           Funko Pop Tv Zorro #1270
# 2  MLA1430696915  Funko Pop Star Wars: Baby Yoda El Mandaloriano...
# 3  MLA1398638469  Figura De Acción  Pikachu 31528 De Funko Pop! ...
# 4  MLA1776662714  Funko Pop Messi 10 Argentina Campeón Mundial C...
#
#   category_id    price
# 0     MLA3422  30163.0
# 1     MLA3422  60490.0
# 2     MLA3422  54590.0
# 3     MLA3422  13500.0
# 4     MLA3422  19999.0

# %%
df.to_csv('output_file.csv', index=False)

# %%
df.describe()
# Out:
#                price
# count     150.000000
# mean    35613.831533
# std     29916.839654
# min      4590.000000
# 25%     17161.750000
# 50%     31900.000000
# 75%     37791.000000
# max    199900.000000
